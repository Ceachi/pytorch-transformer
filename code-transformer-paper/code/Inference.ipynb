# %%
from pathlib import Path
import torch
import torch.nn as nn
from config import get_config, latest_weights_file_path
from train import get_model, get_ds, run_validation
from translate import translate

# %%
# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
config = get_config()
train_dataloader, val_dataloader, tokenizer_src, tokenizer_tgt = get_ds(config)
model = get_model(config, tokenizer_src.get_vocab_size(), tokenizer_tgt.get_vocab_size()).to(device)

# Load the pretrained weights
model_filename = latest_weights_file_path(config)
#model_filename = "/home/bogdan/development/mentorcruise/pytorch-transformer/opus_books_weights/tmodel_00.pt"
print(f"Loading model from {model_filename}")
state = torch.load(model_filename)
model.load_state_dict(state['model_state_dict'])
# Out:
# Using device: cuda
# Max length of source sentence: 309
# Max length of target sentence: 274
# Loading model from opus_books_weights/tmodel_00.pt
# <All keys matched successfully>

# %%
run_validation(model, val_dataloader, tokenizer_src, tokenizer_tgt, config['seq_len'], device, lambda msg: print(msg), 0, None, num_examples=10)
# Out:
# stty: 'standard input': Inappropriate ioctl for device
# --------------------------------------------------------------------------------
#     SOURCE: 'Do you know that the well-known Count Vronsky is going by this train?' remarked the Princess with a triumphant and significant smile, when Koznyshev had found her again and given her the note.
#     TARGET: — Sapete, il conte Vronskij, il famoso... parte con questo treno — disse la principessa con un sorriso trionfante e significativo, mentre egli, ritrovatala, le consegnava il biglietto.
#  PREDICTED: — E che non è fatto che non è fatto che non si può Ivanovic , e che aveva detto , e che aveva detto , e che aveva detto che aveva detto , e che aveva detto , e che aveva detto , e che aveva detto , e che aveva detto , e che si era fatto a lui .
# --------------------------------------------------------------------------------
#     SOURCE: But his good fortune brought about a third event, so that he did not reap the fruit of his rash choice; because, having his auxiliaries routed at Ravenna, and the Switzers having risen and driven out the conquerors (against all expectation, both his and others), it so came to pass that he did not become prisoner to his enemies, they having fled, nor to his auxiliaries, he having conquered by other arms than theirs.
#     TARGET: Ma la sua buona fortuna fece nascere una terza cosa, acciò non cogliessi el frutto della sua mala elezione: perché, sendo li ausiliari sua rotti a Ravenna, e surgendo e' Svizzeri che cacciorono e' vincitori, fuora d’ogni opinione e sua e d'altri, venne a non rimanere prigione delli inimici, sendo fugati, né delli ausiliarii sua, avendo vinto con altre arme che con le loro.
#  PREDICTED: E che era un po ’ di , e che aveva detto , e che era un po ’ un ’ un po ’ un ’ un ’ altra , e che non era un altro di , e che non era stato , e che non era stato , e che non si , e che si , e che si , e che non era a , e che non era a , e che non si , e che non si , e che non si , e che non si a a , e che non si , e che non si a , e che non si , e che non si , e che non era a , e che non si , e che non si a a a , e che non si a a a , e che non si a , e che non si a a , e che non si , e che non si , e , e che non si a a a , e che non si , e che non si , e che non si , e che non era la sua , e che non era un po che non era un po che non era , e che la sua vita , e che non era , e che non era , e che non era , e che non era , e , e , e a , e che non era , e che non era a , e che non era , e che non era a , e che non era il quale la sua vita , e che non era a a
# --------------------------------------------------------------------------------
#     SOURCE: A group of more interest appeared near the hearth, sitting still amidst the rosy peace and warmth suffusing it.
#     TARGET: Presso il focolare vidi un gruppo più interessante.
#  PREDICTED: La sua lettera , e si era un po ’ di , e si era un po ’ di .
# --------------------------------------------------------------------------------
#     SOURCE: She attributed that animosity to the awkward position Anna, who had formerly patronized her, now felt herself to be in, and she was sorry for her.
#     TARGET: Ella spiegò questa ostilità con la situazione di disagio in cui si sentiva adesso, di fronte a lei, Anna che prima la proteggeva, e ne provò pena.
#  PREDICTED: La principessa era un ’ espressione di Levin , e si era già già già già già già già già già già già già già già già già già già già già già , e che aveva detto .
# --------------------------------------------------------------------------------
#     SOURCE: I have lived through sufferings and terrors, but for a long time past – especially since we came here – I have been happy!...' she said, looking at Dolly timidly and with a questioning smile.
#     TARGET: Ho vissuto il tormento e la paura, e ora, già da tempo, ma in particolare da che siamo qui, sono felice!... — ella disse, guardando Dolly con un timido sorriso di domanda.
#  PREDICTED: Non mi , e non , e che non si , e che non si , e che non si , e che non si a lui .
# --------------------------------------------------------------------------------
#     SOURCE: EVERYBODY TOOK PART in the general conversation except Kitty and Levin.
#     TARGET: Tutti prendevano parte alla conversazione generale, tranne Kitty e Levin.
#  PREDICTED: La principessa era un ’ espressione di Levin , e Levin si era già già già già già già già già già già già .
# --------------------------------------------------------------------------------
#     SOURCE: There was no wind stirring to help me, and all I could do with my paddles signified nothing: and now I began to give myself over for lost; for as the current was on both sides of the island, I knew in a few leagues distance they must join again, and then I was irrecoverably gone; nor did I see any possibility of avoiding it; so that I had no prospect before me but of perishing, not by the sea, for that was calm enough, but of starving from hunger.
#     TARGET: Questa si trascinò seco il mio legno con tanta violenza, che tutto il mio saper fare non potendo tenerlo vicino a terra, mi vidi spinto lontano e sempre più lontano dal risucchio che mi stava a manca, e su cui erano fondate le mie speranze. Non spirava un fiato di vento che mi aiutasse, e tutti gli sforzi de’ miei remi non facevano nulla.
#  PREDICTED: , e io non mi , e mi , e che non mi , e che non mi , e che non mi , e che non mi , e che non mi , e che non mi , e che non , e non mi , e che non mi , e che non mi , e che non , e che non mi , e non a a , e che non mi , e che non mi , e che non mi , e che non mi , e che non mi , e che non mi , e che non mi , e che non mi , e che non mi , e , e , e non mi , e che non mi a a , e che non mi a a , e che non mi a me , e che non mi a a , e che non mi , e che non mi , e che non mi , e che non mi , e che non mi , e che non mi , e che non mi , e che non mi , e non mi , e che non mi , e che non mi , e non mi , e che non mi , e che non mi la mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia mia
# --------------------------------------------------------------------------------
#     SOURCE: 'On the balcony.'
#     TARGET: — Sulla terrazza.
#  PREDICTED: — Sì , signore .
# --------------------------------------------------------------------------------
#     SOURCE: Sviyazhsky and Vronsky both played very well and seriously.
#     TARGET: Svijazskij e Vronskij giocavano tutti e due molto bene e con impegno.
#  PREDICTED: Levin si guardò , ma si mise a lui .
# --------------------------------------------------------------------------------
#     SOURCE: "Impatiently I waited for evening, when I might summon you to my presence.
#     TARGET: "Attesi la sera con impazienza, perché allora almeno potevo chiamarvi presso di me.
#  PREDICTED: — Non ho detto che non ho detto che non ho detto .
# --------------------------------------------------------------------------------

# %%
t = translate("Why do I need to translate this?")
# Out:
# Using device: cuda
#     SOURCE: Why do I need to translate this?
#  PREDICTED: Ma che non non non ? ?

# %%
t = translate(34)
# Out:
# Using device: cuda
#         ID: 34
#     SOURCE: And I came out immediately, for I trembled at the idea of being dragged forth by the said Jack.
#     TARGET: Uscii subito, perché mi sgomentavo al pensiero di esser condotta fuori dal mio nascondiglio da John.
#  PREDICTED: Non mi mi mi mi mi mi si  , e , che si si si si si si si si si si si si si  .
